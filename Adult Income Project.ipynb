# %%
import pandas as pd
import numpy as np
data=pd.read_csv('adult.csv')
data.head(10)

#drop empty columns by first checking
#df.isnull()
data=df.replace("?",np.nan)
data=df.dropna()
data
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 0       25       Private  226802          11th                7
# 1       38       Private   89814       HS-grad                9
# 2       28     Local-gov  336951    Assoc-acdm               12
# 3       44       Private  160323  Some-college               10
# 5       34       Private  198693          10th                6
# ...    ...           ...     ...           ...              ...
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation   relationship   race  gender  \
# 0           Never-married  Machine-op-inspct      Own-child  Black    Male
# ...

# %%
#display Top 10 Rows
#data.head(10)
data.info()
data.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 45222 entries, 0 to 48841
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   age              45222 non-null  int64
#  1   workclass        45222 non-null  object
#  2   fnlwgt           45222 non-null  int64
#  3   education        45222 non-null  object
#  4   educational-num  45222 non-null  int64
#  5   marital-status   45222 non-null  object
#  6   occupation       45222 non-null  object
#  7   relationship     45222 non-null  object
#  8   race             45222 non-null  object
#  9   gender           45222 non-null  object
#  10  capital-gain     45222 non-null  int64
#  11  capital-loss     45222 non-null  int64
#  12  hours-per-week   45222 non-null  int64
#  13  native-country   45222 non-null  object
#  14  income           45222 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 5.5+ MB
# (45222, 15)

# %%
data.tail(10)
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 48832   32       Private   34066          10th                6
# 48833   43       Private   84661     Assoc-voc               11
# 48834   32       Private  116138       Masters               14
# 48835   53       Private  321865       Masters               14
# 48836   22       Private  310152  Some-college               10
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation   relationship  \
# 48832  Married-civ-spouse  Handlers-cleaners        Husband
# 48833  Married-civ-spouse              Sales        Husband
# 48834       Never-married       Tech-support  Not-in-family
# ...

# %%
#fetch random samplesfrom dataset
data.sample(frac=0.50)
# Out:
#        age    workclass  fnlwgt  education  educational-num  \
# 898     24      Private  308673    HS-grad                9
# 28985   41  Federal-gov  214838    Masters               14
# 19901   52      Private  363405    HS-grad                9
# 42579   24    Local-gov  103277  Bachelors               13
# 44415   32      Private  260868  Bachelors               13
# ...    ...          ...     ...        ...              ...
# 7866    61      Private  353031    HS-grad                9
# 36571   46      Private  403911    HS-grad                9
# 467     50      Private   44728    HS-grad                9
# 5989    24      Private  588484    HS-grad                9
# 12637   62      Private  217434  Bachelors               13
#
#            marital-status         occupation    relationship   race  gender  \
# 898         Never-married  Handlers-cleaners       Own-child  White    Male
# 28985  Married-civ-spouse    Exec-managerial         Husband  White    Male
# ...

# %%
#check null values
data.isnull
data.dropna(how='any',inplace=True)
data.shape
# Out:
# (45222, 15)

# %%
data=data.duplicated().any()
data

data=data.drop_duplicates()
data.shape
# Out:
# (45175, 15)

# %%
45222-45175
# Out:
# 47

# %%
data.describe()
# Out:
#                 age        fnlwgt  educational-num  capital-gain  \
# count  45175.000000  4.517500e+04     45175.000000  45175.000000
# mean      38.556170  1.897388e+05        10.119314   1102.576270
# std       13.215349  1.056524e+05         2.551740   7510.249876
# min       17.000000  1.349200e+04         1.000000      0.000000
# 25%       28.000000  1.173925e+05         9.000000      0.000000
# 50%       37.000000  1.783120e+05        10.000000      0.000000
# 75%       47.000000  2.379030e+05        13.000000      0.000000
# max       90.000000  1.490400e+06        16.000000  99999.000000
#
#        capital-loss  hours-per-week
# count  45175.000000    45175.000000
# mean      88.687593       40.942512
# std      405.156611       12.007730
# min        0.000000        1.000000
# 25%        0.000000       40.000000
# 50%        0.000000       40.000000
# 75%        0.000000       45.000000
# max     4356.000000       99.000000

# %%
#overall statistics
import pandas as pd
data=pd.read_csv('adult.csv')
data.columns
#data=data.drop(['educational-num',axis=1])
# Out:
#   File "<ipython-input-16-b80ea2a07ae5>", line 5
#     data=data.drop(['educational-num',axis=1])
#                                           ^
# SyntaxError: invalid syntax

# %%
data['age'].describe()
# Out:
# count    48842.000000
# mean        38.643585
# std         13.710510
# min         17.000000
# 25%         28.000000
# 50%         37.000000
# 75%         48.000000
# max         90.000000
# Name: age, dtype: float64

# %%
data['age'].hist()
# Out:
# <AxesSubplot:>

# %%
#Findng total of persons between 17 to 48 using between methods
sum((data['age']>=17)& (data['age']<=48))
sum(data['age'].between(17,48))
# Out:
# 37321

# %%
data['workclass'].describe()
# Out:
# count       48842
# unique          9
# top       Private
# freq        33906
# Name: workclass, dtype: object

# %%
import matplotlib as plt
#plt.figure(figsize=10,10)
data['workclass'].hist()
# Out:
# <AxesSubplot:>
